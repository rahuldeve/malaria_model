# %%
import pandas as pd
import numpy as np
import dill
import rdkit.Chem as Chem
from utils import standardize, set_seeds

import rdkit.Chem as Chem
from rdkit.rdBase import BlockLogs
from rdkit.Chem.MolStandardize import rdMolStandardize
from rdkit.Chem.Descriptors import CalcMolDescriptors
import ray

set_seeds(42)

# %%
chembl_scored_enamine_df = pd.read_csv('./datasets/enamine_liquid_stock_chembl_scored.csv')
chembl_scored_enamine_df = chembl_scored_enamine_df.rename({'id': 'CODE', 'model_score': 'chembl_model_score'}, axis=1)
chembl_scored_enamine_df = chembl_scored_enamine_df.drop(['standard_smiles', 'smiles'], axis=1)

original_enamine_df = pd.read_csv('./datasets/Enamine_Liquid-Stock-Collection_879561cmpds_20240925_filter_wash.txt', sep='\t')

combined_df = chembl_scored_enamine_df.merge(original_enamine_df, on='CODE')
assert (combined_df['CODE'] == combined_df['Molecule Name']).all()

# %%
with open('./saved_models/liver.pkl', 'rb') as infile:
    liver_model = dill.load(infile)

with open('./saved_models/parasite.pkl', 'rb') as infile:
    parasite_model = dill.load(infile)

# %%
def add_features(row):
    with BlockLogs():
        mol = Chem.MolFromInchi(row["inchi"])
        return { **row, **CalcMolDescriptors(mol) }
    

def parasite_model_score(batch, parasite_model):
    with BlockLogs():
        batch["mol"] = batch["inchi"].map(Chem.MolFromInchi)

    try:
        prediction_probs = parasite_model.predict_proba(batch[parasite_model.feature_names_in_])
        predictions = parasite_model.predict(batch[parasite_model.feature_names_in_])
        batch['parasite_prediction_probs'] = prediction_probs[:, 1]
        batch['parasite_prediction'] = predictions
        batch['parasite_threshold'] = parasite_model.best_threshold_
        return batch
    except ValueError:
        batch['parasite_prediction_probs'] = None
        batch['parasite_prediction'] = None
        batch['parasite_threshold'] = None
        return batch

def liver_model_score(batch, liver_model):
    with BlockLogs():
        batch["mol"] = batch["inchi"].map(Chem.MolFromInchi)

    try:
        prediction_probs = liver_model.predict_proba(batch[liver_model.feature_names_in_])
        predictions = liver_model.predict(batch[liver_model.feature_names_in_])
        batch['liver_prediction_probs'] = prediction_probs[:, 1]
        batch['liver_prediction'] = predictions
        batch['liver_threshold'] = liver_model.best_threshold_
        return batch
    except ValueError:
        batch['liver_prediction_probs'] = None
        batch['liver_prediction'] = None
        batch['liver_threshold'] = None
        return batch

# %%
bsize = len(combined_df) // 16
ds = ray.data.from_pandas(combined_df).repartition(bsize)
ds = (
    ds
    .map(lambda row: {**row, 'smiles': row['Smiles']})
    .map(lambda row: {**row, 'inchi': standardize(row['smiles'])})
    .map(add_features)
)


ds = ds.map_batches(
    parasite_model_score,
    fn_args=[parasite_model],
    batch_format="pandas",
)

ds = ds.map_batches(
    liver_model_score,
    fn_args=[liver_model],
    batch_format="pandas",
)

relevant_cols = combined_df.drop(['chembl_model_score'], axis=1).columns.tolist() + [
    'parasite_prediction_probs', 
    'parasite_prediction', 
    'parasite_threshold',
    'liver_prediction_probs', 
    'liver_prediction', 
    'liver_threshold'
]

ds = ds.map_batches(
    lambda batch, cols: batch[cols],
    fn_args=[relevant_cols],
    batch_format="pandas",
    zero_copy_batch=True
)
# Out:
# 2025-01-29 19:43:44,306	INFO worker.py:1777 -- Started a local Ray instance. View the dashboard at 127.0.0.1:8265

# %%
df = ds.to_pandas()
df.to_csv('./enamine_scores.csv')
# Out:
# 2025-01-29 19:43:46,990	INFO streaming_executor.py:108 -- Starting execution of Dataset. Full logs are in /tmp/ray/session_2025-01-29_19-43-43_040694_47318/logs/ray-data
# 2025-01-29 19:43:47,020	INFO streaming_executor.py:109 -- Execution plan of Dataset: InputDataBuffer[Input] -> AllToAllOperator[Repartition] -> TaskPoolMapOperator[Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>)]
# Running 0: 0.00 row [00:00, ? row/s]
# - Repartition 1: 0.00 row [00:00, ? row/s]
# Split Repartition 2:   0%|          | 0.00/1.00 [00:00<?, ? row/s]
# 2025-01-29 19:43:47,114	WARNING progress_bar.py:122 -- Truncating long operator name to 100 characters.To disable this behavior, set `ray.data.DataContext.get_current().DEFAULT_ENABLE_PROGRESS_BAR_NAME_TRUNCATION = False`.
# - Map(<lambda>)->Map(<lambda>)->Map(add_features)->...->MapBatches(<lambda>) 3: 0.00 row [00:00, ? row/s]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47761) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47761)   warnings.warn(
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47758) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 797x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/user-guides/configure-logging.html#log-deduplication for more options.)
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47758)   warnings.warn( [repeated 797x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47756) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 758x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47756)   warnings.warn( [repeated 758x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47755) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 795x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47755)   warnings.warn( [repeated 795x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47783) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 761x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47783)   warnings.warn( [repeated 761x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47769) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 779x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47769)   warnings.warn( [repeated 779x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47783) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 785x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47783)   warnings.warn( [repeated 785x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47758) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 776x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47758)   warnings.warn( [repeated 776x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47783) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 760x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47783)   warnings.warn( [repeated 760x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47783) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 752x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47783)   warnings.warn( [repeated 752x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47783) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 778x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47783)   warnings.warn( [repeated 778x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47783) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 772x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47783)   warnings.warn( [repeated 772x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47762) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 768x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47762)   warnings.warn( [repeated 768x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47758) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 779x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47758)   warnings.warn( [repeated 779x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47772) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 750x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47772)   warnings.warn( [repeated 750x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47764) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 761x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47764)   warnings.warn( [repeated 761x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47758) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 761x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47758)   warnings.warn( [repeated 761x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47772) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 793x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47772)   warnings.warn( [repeated 793x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47757) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 766x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47757)   warnings.warn( [repeated 766x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47758) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 777x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47758)   warnings.warn( [repeated 777x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47772) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 771x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47772)   warnings.warn( [repeated 771x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47758) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 772x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47758)   warnings.warn( [repeated 772x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47760) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 767x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47760)   warnings.warn( [repeated 767x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47758) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 769x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47758)   warnings.warn( [repeated 769x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47771) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 746x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47771)   warnings.warn( [repeated 746x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47758) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 764x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47758)   warnings.warn( [repeated 764x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47771) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 772x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47771)   warnings.warn( [repeated 772x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47783) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 761x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47783)   warnings.warn( [repeated 761x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47762) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 821x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47762)   warnings.warn( [repeated 821x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47760) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 755x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47760)   warnings.warn( [repeated 755x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47783) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 763x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47783)   warnings.warn( [repeated 763x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47758) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 759x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47758)   warnings.warn( [repeated 759x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47762) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 751x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47762)   warnings.warn( [repeated 751x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47758) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 782x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47758)   warnings.warn( [repeated 782x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47783) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 765x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47783)   warnings.warn( [repeated 765x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47764) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 785x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47764)   warnings.warn( [repeated 785x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47760) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 771x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47760)   warnings.warn( [repeated 771x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47757) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 765x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47757)   warnings.warn( [repeated 765x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47762) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 776x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47762)   warnings.warn( [repeated 776x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47762) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 776x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47762)   warnings.warn( [repeated 776x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47757) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 758x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47757)   warnings.warn( [repeated 758x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47758) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 762x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47758)   warnings.warn( [repeated 762x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47772) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 752x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47772)   warnings.warn( [repeated 752x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47764) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 774x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47764)   warnings.warn( [repeated 774x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47783) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 766x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47783)   warnings.warn( [repeated 766x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47762) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 774x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47762)   warnings.warn( [repeated 774x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47772) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 728x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47772)   warnings.warn( [repeated 728x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47783) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 782x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47783)   warnings.warn( [repeated 782x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47783) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 773x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47783)   warnings.warn( [repeated 773x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47758) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 760x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47758)   warnings.warn( [repeated 760x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47762) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 777x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47762)   warnings.warn( [repeated 777x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47783) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 772x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47783)   warnings.warn( [repeated 772x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47758) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 779x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47758)   warnings.warn( [repeated 779x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47764) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 771x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47764)   warnings.warn( [repeated 771x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47762) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 779x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47762)   warnings.warn( [repeated 779x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47783) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 760x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47783)   warnings.warn( [repeated 760x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47758) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 759x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47758)   warnings.warn( [repeated 759x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47760) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 766x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47760)   warnings.warn( [repeated 766x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47764) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 761x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47764)   warnings.warn( [repeated 761x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47758) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 764x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47758)   warnings.warn( [repeated 764x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47762) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 779x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47762)   warnings.warn( [repeated 779x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47760) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 775x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47760)   warnings.warn( [repeated 775x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47758) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 761x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47758)   warnings.warn( [repeated 761x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47755) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 773x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47755)   warnings.warn( [repeated 773x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47760) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 762x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47760)   warnings.warn( [repeated 762x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47758) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 776x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47758)   warnings.warn( [repeated 776x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47783) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 769x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47783)   warnings.warn( [repeated 769x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47783) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 775x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47783)   warnings.warn( [repeated 775x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47757) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 735x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47757)   warnings.warn( [repeated 735x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47758) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 796x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47758)   warnings.warn( [repeated 796x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47783) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 773x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47783)   warnings.warn( [repeated 773x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47783) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 781x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47783)   warnings.warn( [repeated 781x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47757) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 755x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47757)   warnings.warn( [repeated 755x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47758) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 751x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47758)   warnings.warn( [repeated 751x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47762) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 758x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47762)   warnings.warn( [repeated 758x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47783) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 770x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47783)   warnings.warn( [repeated 770x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47772) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 759x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47772)   warnings.warn( [repeated 759x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47783) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 801x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47783)   warnings.warn( [repeated 801x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47771) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 760x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47771)   warnings.warn( [repeated 760x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47772) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 758x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47772)   warnings.warn( [repeated 758x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47758) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 756x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47758)   warnings.warn( [repeated 756x across cluster]
# ...
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47760)   warnings.warn( [repeated 770x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47758) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 769x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47758)   warnings.warn( [repeated 769x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47783) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 763x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47783)   warnings.warn( [repeated 763x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47755) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 755x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47755)   warnings.warn( [repeated 755x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47783) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 759x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47783)   warnings.warn( [repeated 759x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47757) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 770x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47757)   warnings.warn( [repeated 770x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47758) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 768x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47758)   warnings.warn( [repeated 768x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47776) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 768x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47776)   warnings.warn( [repeated 768x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47762) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 747x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47762)   warnings.warn( [repeated 747x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47783) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 780x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47783)   warnings.warn( [repeated 780x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47772) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 749x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47772)   warnings.warn( [repeated 749x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47762) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 753x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47762)   warnings.warn( [repeated 753x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47769) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 787x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47769)   warnings.warn( [repeated 787x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47760) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 771x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47760)   warnings.warn( [repeated 771x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47756) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 775x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47756)   warnings.warn( [repeated 775x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47760) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 754x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47760)   warnings.warn( [repeated 754x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47783) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 771x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47783)   warnings.warn( [repeated 771x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47758) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 775x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47758)   warnings.warn( [repeated 775x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47764) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 766x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47764)   warnings.warn( [repeated 766x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47764) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 746x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47764)   warnings.warn( [repeated 746x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47783) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 764x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47783)   warnings.warn( [repeated 764x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47772) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 778x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47772)   warnings.warn( [repeated 778x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47758) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 758x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47758)   warnings.warn( [repeated 758x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47755) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 697x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47755)   warnings.warn( [repeated 697x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47758) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 766x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47758)   warnings.warn( [repeated 766x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47769) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 798x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47769)   warnings.warn( [repeated 798x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47776) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 747x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47776)   warnings.warn( [repeated 747x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47762) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 759x across cluster]
# (Map(<lambda>)->Map(<lambda>)->Map(add_features)->MapBatches(parasite_model_score)->MapBatches(liver_model_score)->MapBatches(<lambda>) pid=47762)   warnings.warn( [repeated 759x across cluster]

# %%
len(df[
    (df['parasite_prediction'] is True) &
    (df['liver_prediction'] is False)
])
# Out:
# 13230
