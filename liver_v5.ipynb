# %%
import pandas as pd
import numpy as np
from stratified_continious_split import scsplit, ContinuousStratifiedKFold
from utils import standardize_df, add_features, set_seeds
from ray import tune
from ray.tune.search.optuna import OptunaSearch
from feature_pipeline import get_pipeline, get_pipeline_param_space
from utils import calc_scores
from rdkit.Chem.Scaffolds.MurckoScaffold import MurckoScaffoldSmiles
import rdkit.Chem as Chem
from sklearn.model_selection import GroupShuffleSplit, GroupKFold

set_seeds(42)

# %%
def get_scaffold(smi) -> str:
    """
    Generate the Bemis-Murcko scaffold for a given molecule.

    :param smi: A SMILES string or an RDKit molecule object representing the
                molecule for which to generate the scaffold.
    :return: A SMILES string representing the Bemis-Murcko scaffold of the input
             molecule. If the scaffold cannot be generated, the input SMILES
             string is returned.
    """
    scaffold = MurckoScaffoldSmiles(smi)
    if len(scaffold) == 0:
        scaffold = smi
    return scaffold

# %%
def dedupplicate_liver(df, duplicate_selection_criteria):
    uniques = (
        df.groupby("inchi")
        .filter(lambda x: len(x) == 1)[["inchi", "not_cytotoxic_per"]]
        .reset_index(drop=True)
    )
    duplicates = df.groupby("inchi").filter(lambda x: len(x) > 1).reset_index(drop=True)
    deduped = (
        # The inchi keys are the index after groupby; do not drop them but reset the index
        duplicates.groupby("inchi").agg(duplicate_selection_criteria).reset_index()
    )

    return pd.concat([uniques, deduped]).reset_index(drop=True)

# %%
derbyshire_df = pd.read_csv('./datasets/Derbyshire_reg_chembl_scores_corrected.csv').reset_index(drop=True)
derbyshire_df = derbyshire_df[['Compound SMILES', 'liver % average']]

derbyshire_df = derbyshire_df.rename({
    'Compound SMILES': 'smiles',
    'liver % average': 'not_cytotoxic_per'
}, axis=1)

derbyshire_df = standardize_df(derbyshire_df)
derbyshire_df = derbyshire_df[~derbyshire_df['inchi'].isna()].reset_index(drop=True)

duplicate_selection_criteria = {'not_cytotoxic_per': np.max}
derbyshire_df = dedupplicate_liver(derbyshire_df, duplicate_selection_criteria)
derbyshire_df = add_features(derbyshire_df).dropna(axis=0).reset_index(drop=True)

clusters, _ = pd.factorize(
    derbyshire_df['mol']
        .map(Chem.MolToSmiles)
        .map(get_scaffold)
)
clusters = pd.Series(clusters)

derbyshire_df['cytotoxic'] = (derbyshire_df['not_cytotoxic_per'] <= 50).astype(float)

# %%
# df_train_val, df_test = scsplit(derbyshire_df, stratify=derbyshire_df["not_cytotoxic_per"], test_size=0.3, random_state=42)
# df_train_val = df_train_val.reset_index(drop=True)
# df_test = df_test.reset_index(drop=True)

# X_train_val = df_train_val.drop(['cytotoxic', 'not_cytotoxic_per'], axis=1)
# y_train_val = df_train_val['cytotoxic']

# X_test = df_test.drop(['cytotoxic', 'not_cytotoxic_per'], axis=1)
# y_test = df_test['cytotoxic']

splitter = GroupShuffleSplit(n_splits=1, random_state=42)

X = derbyshire_df.drop(['cytotoxic', 'not_cytotoxic_per'], axis=1)
y = derbyshire_df['cytotoxic']
groups = clusters

train_val_idxs, test_idxs = next(splitter.split(X, y, groups))

X_train_val = X.loc[train_val_idxs].reset_index(drop=True)
y_train_val = y.loc[train_val_idxs].reset_index(drop=True)
groups_train_val = groups.loc[train_val_idxs].reset_index(drop=True)

X_test = X.loc[test_idxs].reset_index(drop=True)
y_test = y.loc[test_idxs].reset_index(drop=True)
groups_test = groups.loc[test_idxs].reset_index(drop=True)

# %%
def objective(config, X_train_val, y_train_val, groups_train_val):
    pipeline = get_pipeline()
    pipeline = pipeline.set_params(**config)

    kfold = GroupKFold(n_splits=3, shuffle=True, random_state=42)
    tally = []
    for train_idxs, val_idxs in kfold.split(X_train_val, y_train_val, groups_train_val):
        X_train, y_train = X_train_val.loc[train_idxs], y_train_val.loc[train_idxs]
        X_val, y_val = X_train_val.loc[val_idxs], y_train_val.loc[val_idxs]

        pipeline = pipeline.fit(X_train, y_train)
        y_val_pred_prob = pipeline.predict_proba(X_val)[:, 1]
        y_val_pred = np.where(y_val_pred_prob > 0.5, 1.0, 0.0)

        scores = calc_scores(y_val_pred_prob, y_val_pred, y_val)
        tally.append(scores)

    scores_tally = pd.DataFrame.from_records(tally)
    median_scores = scores_tally.median()
    return median_scores.to_dict()

# %%
tuner = tune.Tuner(
    tune.with_resources(
        tune.with_parameters(
            objective, 
            X_train_val=X_train_val, 
            y_train_val=y_train_val,
            groups_train_val=groups_train_val
        ),
        {'cpu': 4}
    ),
    param_space=get_pipeline_param_space(),
    tune_config=tune.TuneConfig(
        search_alg=OptunaSearch(seed=42),
        num_samples=200,
        metric="average_precision",
        mode="max",
    )
)

# %%
results = tuner.fit()
# Out:
# <div class="tuneStatus">
#   <div style="display: flex;flex-direction: row">
#     <div style="display: flex;flex-direction: column;">
#       <h3>Tune Status</h3>
#       <table>
# <tbody>
# <tr><td>Current time:</td><td>2025-01-29 15:50:54</td></tr>
# <tr><td>Running for: </td><td>00:06:23.98        </td></tr>
# <tr><td>Memory:      </td><td>4.0/117.9 GiB      </td></tr>
# </tbody>
# </table>
#     </div>
#     <div class="vDivider"></div>
#     <div class="systemInfo">
#       <h3>System Info</h3>
#       Using FIFO scheduling algorithm.<br>Logical resource usage: 4.0/30 CPUs, 0/0 GPUs
#     </div>
#
#   </div>
#   <div class="hDivider"></div>
#   <div class="trialStatus">
#     <h3>Trial Status</h3>
#     <table>
# <thead>
# <tr><th>Trial name        </th><th>status    </th><th>loc                </th><th style="text-align: right;">     featureunion__morgan
# fp__n_bits</th><th style="text-align: right;">         ...line__correlation
# threshold__threshold</th><th style="text-align: right;">          ...ipeline__variance
# threshold__threshold</th><th style="text-align: right;">         lgbmclassifier__cols
# ample_bytree</th><th style="text-align: right;">   lgbmclassifier__max_
# depth</th><th style="text-align: right;">   lgbmclassifier__min_
# child_samples</th><th style="text-align: right;">    lgbmclassifier__n_es
# timators</th><th style="text-align: right;">    lgbmclassifier__num_
# leaves</th><th style="text-align: right;">            lgbmclassifier__reg_
# alpha</th><th style="text-align: right;">            lgbmclassifier__reg_
# lambda</th><th style="text-align: right;">    lgbmclassifier__scal
# e_pos_weight</th><th style="text-align: right;">         lgbmclassifier__subs
# ample</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  accuracy</th><th style="text-align: right;">  balanced_accuracy</th><th style="text-align: right;">       f1</th></tr>
# </thead>
# <tbody>
# <tr><td>objective_b427c038</td><td>TERMINATED</td><td>10.128.15.205:4801 </td><td style="text-align: right;"> 512</td><td style="text-align: right;">0.990143</td><td style="text-align: right;">0.143635 </td><td style="text-align: right;">0.118526</td><td style="text-align: right;">13</td><td style="text-align: right;">97</td><td style="text-align: right;">251</td><td style="text-align: right;">154</td><td style="text-align: right;">2.55026e-08</td><td style="text-align: right;">0.0115673  </td><td style="text-align: right;"> 88</td><td style="text-align: right;">0.737265</td><td style="text-align: right;">     1</td><td style="text-align: right;">         2.56629</td><td style="text-align: right;">  0.978282</td><td style="text-align: right;">           0.54483 </td><td style="text-align: right;">0.153846 </td></tr>
# <tr><td>objective_ea4e29ca</td><td>TERMINATED</td><td>10.128.15.205:4926 </td><td style="text-align: right;">4096</td><td style="text-align: right;">0.860848</td><td style="text-align: right;">0.0958511</td><td style="text-align: right;">0.806658</td><td style="text-align: right;"> 7</td><td style="text-align: right;">23</td><td style="text-align: right;">612</td><td style="text-align: right;"> 95</td><td style="text-align: right;">9.47233e-08</td><td style="text-align: right;">1.10921e-06</td><td style="text-align: right;"> 66</td><td style="text-align: right;">0.510463</td><td style="text-align: right;">     1</td><td style="text-align: right;">        10.3314 </td><td style="text-align: right;">  0.980257</td><td style="text-align: right;">           0.499497</td><td style="text-align: right;">0        </td></tr>
# <tr><td>objective_ec9f1305</td><td>TERMINATED</td><td>10.128.15.205:5203 </td><td style="text-align: right;">2048</td><td style="text-align: right;">0.834105</td><td style="text-align: right;">0.201886 </td><td style="text-align: right;">0.209834</td><td style="text-align: right;">16</td><td style="text-align: right;">52</td><td style="text-align: right;">913</td><td style="text-align: right;">175</td><td style="text-align: right;">1.35611e-06</td><td style="text-align: right;">4.82731e-08</td><td style="text-align: right;"> 32</td><td style="text-align: right;">0.496137</td><td style="text-align: right;">     1</td><td style="text-align: right;">         8.79909</td><td style="text-align: right;">  0.980257</td><td style="text-align: right;">           0.499497</td><td style="text-align: right;">0        </td></tr>
# <tr><td>objective_27bae8a2</td><td>TERMINATED</td><td>10.128.15.205:5317 </td><td style="text-align: right;">4096</td><td style="text-align: right;">0.862342</td><td style="text-align: right;">0.215631 </td><td style="text-align: right;">0.929687</td><td style="text-align: right;">19</td><td style="text-align: right;">13</td><td style="text-align: right;"> 92</td><td style="text-align: right;">229</td><td style="text-align: right;">0.00266643 </td><td style="text-align: right;">0.0377131  </td><td style="text-align: right;"> 44</td><td style="text-align: right;">0.63811 </td><td style="text-align: right;">     1</td><td style="text-align: right;">         4.08651</td><td style="text-align: right;">  0.98262 </td><td style="text-align: right;">           0.54483 </td><td style="text-align: right;">0.153846 </td></tr>
# <tr><td>objective_5f8ef1f5</td><td>TERMINATED</td><td>10.128.15.205:5414 </td><td style="text-align: right;"> 512</td><td style="text-align: right;">0.85427 </td><td style="text-align: right;">0.147169 </td><td style="text-align: right;">0.79502 </td><td style="text-align: right;">36</td><td style="text-align: right;">23</td><td style="text-align: right;">824</td><td style="text-align: right;"> 20</td><td style="text-align: right;">9.69325e-08</td><td style="text-align: right;">0.00412457 </td><td style="text-align: right;"> 30</td><td style="text-align: right;">0.988198</td><td style="text-align: right;">     1</td><td style="text-align: right;">         9.72199</td><td style="text-align: right;">  0.980257</td><td style="text-align: right;">           0.531287</td><td style="text-align: right;">0.105263 </td></tr>
# <tr><td>objective_3f193b48</td><td>TERMINATED</td><td>10.128.15.205:5514 </td><td style="text-align: right;">4096</td><td style="text-align: right;">0.954254</td><td style="text-align: right;">0.232252 </td><td style="text-align: right;">0.392665</td><td style="text-align: right;">26</td><td style="text-align: right;">74</td><td style="text-align: right;">892</td><td style="text-align: right;"> 18</td><td style="text-align: right;">0.000230721</td><td style="text-align: right;">2.07151e-06</td><td style="text-align: right;"> 74</td><td style="text-align: right;">0.379884</td><td style="text-align: right;">     1</td><td style="text-align: right;">         8.75151</td><td style="text-align: right;">  0.979269</td><td style="text-align: right;">           0.498994</td><td style="text-align: right;">0        </td></tr>
# <tr><td>objective_d9feea65</td><td>TERMINATED</td><td>10.128.15.205:5619 </td><td style="text-align: right;">2048</td><td style="text-align: right;">0.942649</td><td style="text-align: right;">0.0798986</td><td style="text-align: right;">0.128286</td><td style="text-align: right;">45</td><td style="text-align: right;">65</td><td style="text-align: right;">533</td><td style="text-align: right;">  8</td><td style="text-align: right;">4.56173e-05</td><td style="text-align: right;">9.83529e-06</td><td style="text-align: right;"> 52</td><td style="text-align: right;">0.197102</td><td style="text-align: right;">     1</td><td style="text-align: right;">         4.18478</td><td style="text-align: right;">  0.980257</td><td style="text-align: right;">           0.54483 </td><td style="text-align: right;">0.153846 </td></tr>
# <tr><td>objective_8f92b3a8</td><td>TERMINATED</td><td>10.128.15.205:5719 </td><td style="text-align: right;"> 512</td><td style="text-align: right;">0.882077</td><td style="text-align: right;">0.112323 </td><td style="text-align: right;">0.884315</td><td style="text-align: rig
# (objective pid=4801) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# (objective pid=4801)   warnings.warn(
# (objective pid=4801) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# (objective pid=4801)   warnings.warn(
# (objective pid=4801) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# (objective pid=4801)   warnings.warn(
# (objective pid=4801) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# (objective pid=4801)   warnings.warn(
# (objective pid=4801) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# (objective pid=4801)   warnings.warn(
# (objective pid=4801) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# (objective pid=4801)   warnings.warn(
# (objective pid=4926) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 4x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/user-guides/configure-logging.html#log-deduplication for more options.)
# (objective pid=4926)   warnings.warn( [repeated 4x across cluster]
# (objective pid=5414) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 15x across cluster]
# (objective pid=5414)   warnings.warn( [repeated 15x across cluster]
# (objective pid=5819) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 17x across cluster]
# (objective pid=5819)   warnings.warn( [repeated 17x across cluster]
# (objective pid=6018) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 19x across cluster]
# (objective pid=6018)   warnings.warn( [repeated 19x across cluster]
# (objective pid=6212) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 15x across cluster]
# (objective pid=6212)   warnings.warn( [repeated 15x across cluster]
# (objective pid=6510) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 20x across cluster]
# (objective pid=6510)   warnings.warn( [repeated 20x across cluster]
# (objective pid=6710) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 10x across cluster]
# (objective pid=6710)   warnings.warn( [repeated 10x across cluster]
# (objective pid=6810) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 14x across cluster]
# (objective pid=6810)   warnings.warn( [repeated 14x across cluster]
# (objective pid=7207) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 18x across cluster]
# (objective pid=7207)   warnings.warn( [repeated 18x across cluster]
# (objective pid=7306) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 12x across cluster]
# (objective pid=7306)   warnings.warn( [repeated 12x across cluster]
# (objective pid=7804) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 20x across cluster]
# (objective pid=7804)   warnings.warn( [repeated 20x across cluster]
# (objective pid=8107) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 17x across cluster]
# (objective pid=8107)   warnings.warn( [repeated 17x across cluster]
# (objective pid=8201) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 15x across cluster]
# (objective pid=8201)   warnings.warn( [repeated 15x across cluster]
# (objective pid=8703) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 18x across cluster]
# (objective pid=8703)   warnings.warn( [repeated 18x across cluster]
# (objective pid=8603) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
# (objective pid=8603)   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# (objective pid=8901) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 16x across cluster]
# (objective pid=8901)   warnings.warn( [repeated 16x across cluster]
# (objective pid=9193) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 20x across cluster]
# (objective pid=9193)   warnings.warn( [repeated 20x across cluster]
# (objective pid=9490) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 17x across cluster]
# (objective pid=9490)   warnings.warn( [repeated 17x across cluster]
# (objective pid=9687) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 16x across cluster]
# (objective pid=9687)   warnings.warn( [repeated 16x across cluster]
# (objective pid=10075) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 13x across cluster]
# (objective pid=10075)   warnings.warn( [repeated 13x across cluster]
# (objective pid=10273) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 19x across cluster]
# (objective pid=10273)   warnings.warn( [repeated 19x across cluster]
# (objective pid=10569) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 18x across cluster]
# (objective pid=10569)   warnings.warn( [repeated 18x across cluster]
# (objective pid=10767) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 16x across cluster]
# (objective pid=10767)   warnings.warn( [repeated 16x across cluster]
# (objective pid=11056) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 18x across cluster]
# (objective pid=11056)   warnings.warn( [repeated 18x across cluster]
# (objective pid=11352) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 16x across cluster]
# (objective pid=11352)   warnings.warn( [repeated 16x across cluster]
# (objective pid=11641) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 17x across cluster]
# (objective pid=11641)   warnings.warn( [repeated 17x across cluster]
# (objective pid=11937) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 13x across cluster]
# (objective pid=11937)   warnings.warn( [repeated 13x across cluster]
# (objective pid=12333) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 18x across cluster]
# (objective pid=12333)   warnings.warn( [repeated 18x across cluster]
# (objective pid=12333) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 20x across cluster]
# (objective pid=12333)   warnings.warn( [repeated 20x across cluster]
# (objective pid=12727) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 18x across cluster]
# (objective pid=12727)   warnings.warn( [repeated 18x across cluster]
# (objective pid=13024) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 14x across cluster]
# (objective pid=13024)   warnings.warn( [repeated 14x across cluster]
# (objective pid=13321) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 20x across cluster]
# (objective pid=13321)   warnings.warn( [repeated 20x across cluster]
# (objective pid=13613) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 17x across cluster]
# (objective pid=13613)   warnings.warn( [repeated 17x across cluster]
# (objective pid=13908) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 16x across cluster]
# (objective pid=13908)   warnings.warn( [repeated 16x across cluster]
# (objective pid=14104) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 15x across cluster]
# (objective pid=14104)   warnings.warn( [repeated 15x across cluster]
# (objective pid=14401) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 18x across cluster]
# (objective pid=14401)   warnings.warn( [repeated 18x across cluster]
# (objective pid=14691) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 17x across cluster]
# (objective pid=14691)   warnings.warn( [repeated 17x across cluster]
# (objective pid=14987) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 17x across cluster]
# (objective pid=14987)   warnings.warn( [repeated 17x across cluster]
# (objective pid=15282) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 17x across cluster]
# (objective pid=15282)   warnings.warn( [repeated 17x across cluster]
# (objective pid=15474) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 16x across cluster]
# (objective pid=15474)   warnings.warn( [repeated 16x across cluster]
# (objective pid=15769) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 15x across cluster]
# (objective pid=15769)   warnings.warn( [repeated 15x across cluster]
# (objective pid=16066) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 18x across cluster]
# (objective pid=16066)   warnings.warn( [repeated 18x across cluster]
# (objective pid=16258) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 12x across cluster]
# (objective pid=16258)   warnings.warn( [repeated 12x across cluster]
# (objective pid=16653) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 16x across cluster]
# (objective pid=16653)   warnings.warn( [repeated 16x across cluster]
# (objective pid=16851) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 19x across cluster]
# (objective pid=16851)   warnings.warn( [repeated 19x across cluster]
# (objective pid=17150) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 19x across cluster]
# (objective pid=17150)   warnings.warn( [repeated 19x across cluster]
# (objective pid=17441) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 17x across cluster]
# (objective pid=17441)   warnings.warn( [repeated 17x across cluster]
# (objective pid=17638) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 15x across cluster]
# (objective pid=17638)   warnings.warn( [repeated 15x across cluster]
# (objective pid=18034) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 20x across cluster]
# (objective pid=18034)   warnings.warn( [repeated 20x across cluster]
# (objective pid=18224) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 15x across cluster]
# (objective pid=18224)   warnings.warn( [repeated 15x across cluster]
# (objective pid=18520) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 16x across cluster]
# (objective pid=18520)   warnings.warn( [repeated 16x across cluster]
# (objective pid=18816) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 18x across cluster]
# (objective pid=18816)   warnings.warn( [repeated 18x across cluster]
# (objective pid=19007) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 15x across cluster]
# (objective pid=19007)   warnings.warn( [repeated 15x across cluster]
# (objective pid=19302) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 18x across cluster]
# (objective pid=19302)   warnings.warn( [repeated 18x across cluster]
# (objective pid=19599) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 17x across cluster]
# (objective pid=19599)   warnings.warn( [repeated 17x across cluster]
# (objective pid=19888) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 17x across cluster]
# (objective pid=19888)   warnings.warn( [repeated 17x across cluster]
# (objective pid=20184) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 17x across cluster]
# (objective pid=20184)   warnings.warn( [repeated 17x across cluster]
# (objective pid=20381) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 16x across cluster]
# (objective pid=20381)   warnings.warn( [repeated 16x across cluster]
# (objective pid=20671) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 17x across cluster]
# (objective pid=20671)   warnings.warn( [repeated 17x across cluster]
# (objective pid=20966) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 16x across cluster]
# (objective pid=20966)   warnings.warn( [repeated 16x across cluster]
# (objective pid=21262) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 16x across cluster]
# (objective pid=21262)   warnings.warn( [repeated 16x across cluster]
# (objective pid=21459) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 16x across cluster]
# (objective pid=21459)   warnings.warn( [repeated 16x across cluster]
# (objective pid=21749) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 17x across cluster]
# (objective pid=21749)   warnings.warn( [repeated 17x across cluster]
# (objective pid=22044) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 17x across cluster]
# (objective pid=22044)   warnings.warn( [repeated 17x across cluster]
# (objective pid=22340) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 17x across cluster]
# (objective pid=22340)   warnings.warn( [repeated 17x across cluster]
# (objective pid=22631) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 15x across cluster]
# (objective pid=22631)   warnings.warn( [repeated 15x across cluster]
# (objective pid=22829) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 17x across cluster]
# (objective pid=22829)   warnings.warn( [repeated 17x across cluster]
# (objective pid=23124) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 18x across cluster]
# (objective pid=23124)   warnings.warn( [repeated 18x across cluster]
# (objective pid=23415) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 15x across cluster]
# (objective pid=23415)   warnings.warn( [repeated 15x across cluster]
# (objective pid=23612) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 16x across cluster]
# (objective pid=23612)   warnings.warn( [repeated 16x across cluster]
# (objective pid=23810) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 15x across cluster]
# (objective pid=23810)   warnings.warn( [repeated 15x across cluster]
# (objective pid=24198) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 16x across cluster]
# (objective pid=24198)   warnings.warn( [repeated 16x across cluster]
# (objective pid=24396) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 19x across cluster]
# (objective pid=24396)   warnings.warn( [repeated 19x across cluster]
# 2025-01-29 15:50:54,604	INFO tune.py:1009 -- Wrote the latest version of all result files and experiment state to '/home/rahul_e_dev/ray_results/objective_2025-01-29_15-44-25' in 0.0656s.
# 2025-01-29 15:50:54,658	INFO tune.py:1041 -- Total run time: 384.08 seconds (383.91 seconds for the tuning loop).

# %%
from sklearn.model_selection import TunedThresholdClassifierCV

best_result = results.get_best_result()
pipeline = get_pipeline()
config = {k:v for k,v in best_result.config.items() if k in pipeline.get_params()}
pipeline.set_params(**config)

pipeline = pipeline.fit(X_train_val, y_train_val)

kfold = ContinuousStratifiedKFold(n_splits=3)
th_pipeline = TunedThresholdClassifierCV(pipeline, scoring='f1', cv=kfold, thresholds=500)
th_pipeline.fit(X_train_val, y_train_val)

y_test_pred_prob = th_pipeline.predict_proba(X_test)[:, 1]
y_test_pred = th_pipeline.predict(X_test)
test_scores = calc_scores(y_test_pred_prob, y_test_pred, y_test.to_numpy())
test_scores = {k: np.round(v, 3) for k, v in test_scores.items()}
test_scores
# Out:
# /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# {'accuracy': 0.978,
#  'balanced_accuracy': 0.539,
#  'f1': 0.125,
#  'precision': 0.25,
#  'recall': 0.083,
#  'roc_auc': 0.665,
#  'average_precision': 0.049,
#  'specificity': 0.995,
#  'sensitivity': 0.083,
#  'test_delong_auc': 0.665,
#  'lb': 0.543,
#  'ub': 0.787}

# %%
best_result.metrics_dataframe
# Out:
#    accuracy  balanced_accuracy        f1  precision    recall  roc_auc  \
# 0  0.983957            0.54358  0.133333       0.25  0.090909  0.82767
#
#    average_precision  specificity  sensitivity  test_delong_auc  ...  \
# 0           0.159418     0.998636     0.090909          0.82767  ...
#
#    config/lgbmclassifier__reg_lambda  config/lgbmclassifier__num_leaves  \
# 0                           0.085609                                196
#
#    config/lgbmclassifier__subsample config/lgbmclassifier__colsample_bytree  \
# 0                          0.676629                                0.176909
#
#    config/lgbmclassifier__min_child_samples  config/lgbmclassifier__n_jobs  \
# 0                                        48                              4
#
#   config/lgbmclassifier__random_state config/lgbmclassifier__scale_pos_weight  \
# 0                                  42                                      54
#
#    config/lgbmclassifier__n_estimators  config/lgbmclassifier__max_depth
# 0                                  104                                35
#
# [1 rows x 43 columns]

# %%
import dill

with open('./saved_models/liver.pkl', 'wb') as outfile:
    dill.dump(th_pipeline, outfile)

# %%
# from sklearn.model_selection import TunedThresholdClassifierCV

# best_result = results.get_best_result()
# pipeline = get_pipeline()
# config = {k:v for k,v in best_result.config.items() if k in pipeline.get_params()}
# pipeline.set_params(**config)

# pipeline = pipeline.fit(X_train_val, y_train_val)

# kfold = ContinuousStratifiedKFold(n_splits=3)
# th_pipeline = TunedThresholdClassifierCV(pipeline, scoring='f1', cv=kfold, thresholds=500)
# th_pipeline.fit(X_train_val, y_train_val)

# y_test_pred_prob = th_pipeline.predict_proba(X_test)[:, 1]
# y_test_pred = th_pipeline.predict(X_test)
# test_scores = calc_scores(y_test_pred_prob, y_test_pred, y_test.to_numpy())
# test_scores = {k: np.round(v, 3) for k, v in test_scores.items()}
# test_scores

# %%
# best_result.metrics_dataframe
