# %%
import pandas as pd
import numpy as np
import rdkit.Chem as Chem
from stratified_continious_split import scsplit, ContinuousStratifiedKFold
from rdkit.Chem.Scaffolds.MurckoScaffold import MurckoScaffoldSmiles
from utils import standardize_df, add_features, set_seeds
from sklearn.model_selection import GroupShuffleSplit, GroupKFold
from ray import tune
from ray.tune.search.optuna import OptunaSearch
from feature_pipeline import get_pipeline, get_pipeline_param_space
from utils import calc_scores

set_seeds(42)

# %%
def get_scaffold(smi) -> str:
    """
    Generate the Bemis-Murcko scaffold for a given molecule.

    :param smi: A SMILES string or an RDKit molecule object representing the
                molecule for which to generate the scaffold.
    :return: A SMILES string representing the Bemis-Murcko scaffold of the input
             molecule. If the scaffold cannot be generated, the input SMILES
             string is returned.
    """
    scaffold = MurckoScaffoldSmiles(smi)
    if len(scaffold) == 0:
        scaffold = smi
    return scaffold

# %%
def dedupplicate_parasite(df, duplicate_selection_criteria):
    uniques = (
        df.groupby("inchi")
        .filter(lambda x: len(x) == 1)[["inchi", "chembl_model_score", "par_inhibition_per"]]
        .reset_index(drop=True)
    )
    duplicates = df.groupby("inchi").filter(lambda x: len(x) > 1).reset_index(drop=True)
    deduped = (
        # The inchi keys are the index after groupby; do not drop them but reset the index
        duplicates.groupby("inchi").agg(duplicate_selection_criteria).reset_index()
    )

    return pd.concat([uniques, deduped]).reset_index(drop=True)

# %%
derbyshire_df = pd.read_csv('./datasets/Derbyshire_reg_chembl_scores_corrected.csv').reset_index(drop=True)
derbyshire_df = derbyshire_df[['Compound SMILES', 'parasite % average', 'chembl_model_score']]

derbyshire_df = derbyshire_df.rename({
    'Compound SMILES': 'smiles',
    'parasite % average': 'par_inhibition_per',
}, axis=1)

derbyshire_df = standardize_df(derbyshire_df)
derbyshire_df = derbyshire_df[~derbyshire_df['inchi'].isna()].reset_index(drop=True)

duplicate_selection_criteria = {'par_inhibition_per': np.min, 'chembl_model_score': np.max}
derbyshire_df = dedupplicate_parasite(derbyshire_df, duplicate_selection_criteria)
derbyshire_df = add_features(derbyshire_df).dropna(axis=0).reset_index(drop=True)

clusters, _ = pd.factorize(
    derbyshire_df['mol']
        .map(Chem.MolToSmiles)
        .map(get_scaffold)
)
clusters = pd.Series(clusters)
# derbyshire_df['cluster'] = factorized

derbyshire_df["inhibit_parasite"] = (derbyshire_df["par_inhibition_per"] <= 15.0).astype(float)

# %%
splitter = GroupShuffleSplit(n_splits=1, random_state=42)

X = derbyshire_df.drop(['inhibit_parasite', 'par_inhibition_per'], axis=1)
y = derbyshire_df['inhibit_parasite']
groups = clusters

train_val_idxs, test_idxs = next(splitter.split(X, y, groups))

X_train_val = X.loc[train_val_idxs].reset_index(drop=True)
y_train_val = y.loc[train_val_idxs].reset_index(drop=True)
groups_train_val = groups.loc[train_val_idxs].reset_index(drop=True)

X_test = X.loc[test_idxs].reset_index(drop=True)
y_test = y.loc[test_idxs].reset_index(drop=True)
groups_test = groups.loc[test_idxs].reset_index(drop=True)

# %%
def objective(config, X_train_val, y_train_val, groups_train_val):
    pipeline = get_pipeline()
    pipeline = pipeline.set_params(**config)

    kfold = GroupKFold(n_splits=3, shuffle=True, random_state=42)
    tally = []
    for train_idxs, val_idxs in kfold.split(X_train_val, y_train_val, groups_train_val):
        X_train, y_train = X_train_val.loc[train_idxs], y_train_val.loc[train_idxs]
        X_val, y_val = X_train_val.loc[val_idxs], y_train_val.loc[val_idxs]

        pipeline = pipeline.fit(X_train, y_train)
        y_val_pred_prob = pipeline.predict_proba(X_val)[:, 1]
        y_val_pred = np.where(y_val_pred_prob > 0.5, 1.0, 0.0)

        scores = calc_scores(y_val_pred_prob, y_val_pred, y_val)
        tally.append(scores)

    scores_tally = pd.DataFrame.from_records(tally)
    median_scores = scores_tally.median()
    return median_scores.to_dict()

# %%
tuner = tune.Tuner(
    tune.with_resources(
        tune.with_parameters(
            objective, 
            X_train_val=X_train_val, 
            y_train_val=y_train_val,
            groups_train_val=groups_train_val
        ),
        {'cpu': 4}
    ),
    param_space=get_pipeline_param_space(),
    tune_config=tune.TuneConfig(
        search_alg=OptunaSearch(seed=42),
        num_samples=200,
        metric="average_precision",
        mode="max",
    )
)

# %%
results = tuner.fit()
# Out:
# <div class="tuneStatus">
#   <div style="display: flex;flex-direction: row">
#     <div style="display: flex;flex-direction: column;">
#       <h3>Tune Status</h3>
#       <table>
# <tbody>
# <tr><td>Current time:</td><td>2025-01-29 15:34:25</td></tr>
# <tr><td>Running for: </td><td>00:07:17.81        </td></tr>
# <tr><td>Memory:      </td><td>4.2/117.9 GiB      </td></tr>
# </tbody>
# </table>
#     </div>
#     <div class="vDivider"></div>
#     <div class="systemInfo">
#       <h3>System Info</h3>
#       Using FIFO scheduling algorithm.<br>Logical resource usage: 4.0/30 CPUs, 0/0 GPUs
#     </div>
#
#   </div>
#   <div class="hDivider"></div>
#   <div class="trialStatus">
#     <h3>Trial Status</h3>
#     <table>
# <thead>
# <tr><th>Trial name        </th><th>status    </th><th>loc                </th><th style="text-align: right;">     featureunion__morgan
# fp__n_bits</th><th style="text-align: right;">         ...line__correlation
# threshold__threshold</th><th style="text-align: right;">          ...ipeline__variance
# threshold__threshold</th><th style="text-align: right;">         lgbmclassifier__cols
# ample_bytree</th><th style="text-align: right;">   lgbmclassifier__max_
# depth</th><th style="text-align: right;">   lgbmclassifier__min_
# child_samples</th><th style="text-align: right;">    lgbmclassifier__n_es
# timators</th><th style="text-align: right;">    lgbmclassifier__num_
# leaves</th><th style="text-align: right;">            lgbmclassifier__reg_
# alpha</th><th style="text-align: right;">            lgbmclassifier__reg_
# lambda</th><th style="text-align: right;">    lgbmclassifier__scal
# e_pos_weight</th><th style="text-align: right;">         lgbmclassifier__subs
# ample</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  accuracy</th><th style="text-align: right;">  balanced_accuracy</th><th style="text-align: right;">      f1</th></tr>
# </thead>
# <tbody>
# <tr><td>objective_478d1020</td><td>TERMINATED</td><td>10.128.15.205:13591</td><td style="text-align: right;"> 512</td><td style="text-align: right;">0.990143</td><td style="text-align: right;">0.143635 </td><td style="text-align: right;">0.118526</td><td style="text-align: right;">13</td><td style="text-align: right;">97</td><td style="text-align: right;">251</td><td style="text-align: right;">154</td><td style="text-align: right;">2.55026e-08</td><td style="text-align: right;">0.0115673  </td><td style="text-align: right;"> 88</td><td style="text-align: right;">0.737265</td><td style="text-align: right;">     1</td><td style="text-align: right;">         2.57247</td><td style="text-align: right;">  0.669785</td><td style="text-align: right;">           0.656724</td><td style="text-align: right;">0.235616</td></tr>
# <tr><td>objective_434ec544</td><td>TERMINATED</td><td>10.128.15.205:13713</td><td style="text-align: right;">4096</td><td style="text-align: right;">0.860848</td><td style="text-align: right;">0.0958511</td><td style="text-align: right;">0.806658</td><td style="text-align: right;"> 7</td><td style="text-align: right;">23</td><td style="text-align: right;">612</td><td style="text-align: right;"> 95</td><td style="text-align: right;">9.47233e-08</td><td style="text-align: right;">1.10921e-06</td><td style="text-align: right;"> 66</td><td style="text-align: right;">0.510463</td><td style="text-align: right;">     1</td><td style="text-align: right;">        11.401  </td><td style="text-align: right;">  0.902778</td><td style="text-align: right;">           0.580548</td><td style="text-align: right;">0.230088</td></tr>
# <tr><td>objective_ce863fa5</td><td>TERMINATED</td><td>10.128.15.205:13843</td><td style="text-align: right;">2048</td><td style="text-align: right;">0.834105</td><td style="text-align: right;">0.201886 </td><td style="text-align: right;">0.209834</td><td style="text-align: right;">16</td><td style="text-align: right;">52</td><td style="text-align: right;">913</td><td style="text-align: right;">175</td><td style="text-align: right;">1.35611e-06</td><td style="text-align: right;">4.82731e-08</td><td style="text-align: right;"> 32</td><td style="text-align: right;">0.496137</td><td style="text-align: right;">     1</td><td style="text-align: right;">         9.93545</td><td style="text-align: right;">  0.914141</td><td style="text-align: right;">           0.545752</td><td style="text-align: right;">0.16092 </td></tr>
# <tr><td>objective_b6397bf3</td><td>TERMINATED</td><td>10.128.15.205:14113</td><td style="text-align: right;">4096</td><td style="text-align: right;">0.862342</td><td style="text-align: right;">0.215631 </td><td style="text-align: right;">0.929687</td><td style="text-align: right;">19</td><td style="text-align: right;">13</td><td style="text-align: right;"> 92</td><td style="text-align: right;">229</td><td style="text-align: right;">0.00266643 </td><td style="text-align: right;">0.0377131  </td><td style="text-align: right;"> 44</td><td style="text-align: right;">0.63811 </td><td style="text-align: right;">     1</td><td style="text-align: right;">         5.56519</td><td style="text-align: right;">  0.89899 </td><td style="text-align: right;">           0.5249  </td><td style="text-align: right;">0.111111</td></tr>
# <tr><td>objective_5a309461</td><td>TERMINATED</td><td>10.128.15.205:14204</td><td style="text-align: right;"> 512</td><td style="text-align: right;">0.85427 </td><td style="text-align: right;">0.147169 </td><td style="text-align: right;">0.79502 </td><td style="text-align: right;">36</td><td style="text-align: right;">23</td><td style="text-align: right;">824</td><td style="text-align: right;"> 20</td><td style="text-align: right;">9.69325e-08</td><td style="text-align: right;">0.00412457 </td><td style="text-align: right;"> 30</td><td style="text-align: right;">0.988198</td><td style="text-align: right;">     1</td><td style="text-align: right;">        12.389  </td><td style="text-align: right;">  0.915404</td><td style="text-align: right;">           0.538289</td><td style="text-align: right;">0.139535</td></tr>
# <tr><td>objective_0e5c8f3f</td><td>TERMINATED</td><td>10.128.15.205:14303</td><td style="text-align: right;">4096</td><td style="text-align: right;">0.954254</td><td style="text-align: right;">0.232252 </td><td style="text-align: right;">0.392665</td><td style="text-align: right;">26</td><td style="text-align: right;">74</td><td style="text-align: right;">892</td><td style="text-align: right;"> 18</td><td style="text-align: right;">0.000230721</td><td style="text-align: right;">2.07151e-06</td><td style="text-align: right;"> 74</td><td style="text-align: right;">0.379884</td><td style="text-align: right;">     1</td><td style="text-align: right;">        10.5192 </td><td style="text-align: right;">  0.905303</td><td style="text-align: right;">           0.557162</td><td style="text-align: right;">0.178571</td></tr>
# <tr><td>objective_ffa49d99</td><td>TERMINATED</td><td>10.128.15.205:14409</td><td style="text-align: right;">2048</td><td style="text-align: right;">0.942649</td><td style="text-align: right;">0.0798986</td><td style="text-align: right;">0.128286</td><td style="text-align: right;">45</td><td style="text-align: right;">65</td><td style="text-align: right;">533</td><td style="text-align: right;">  8</td><td style="text-align: right;">4.56173e-05</td><td style="text-align: right;">9.83529e-06</td><td style="text-align: right;"> 52</td><td style="text-align: right;">0.197102</td><td style="text-align: right;">     1</td><td style="text-align: right;">         4.64787</td><td style="text-align: right;">  0.750234</td><td style="text-align: right;">           0.607342</td><td style="text-align: right;">0.24    </td></tr>
# <tr><td>objective_dcd3f495</td><td>TERMINATED</td><td>10.128.15.205:14508</td><td style="text-align: right;"> 512</td><td style="text-align: right;">0.882077</td><td style="text-align: right;">0.112323 </td><td style="text-align: right;">0.884315</td><td style="text-align: right;">29<
# (objective pid=13591) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# (objective pid=13591)   warnings.warn(
# (objective pid=13591) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# (objective pid=13591)   warnings.warn(
# (objective pid=13591) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# (objective pid=13591)   warnings.warn(
# (objective pid=13591) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# (objective pid=13591)   warnings.warn(
# (objective pid=13591) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# (objective pid=13591)   warnings.warn(
# (objective pid=13591) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# (objective pid=13591)   warnings.warn(
# (objective pid=13713) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 4x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/user-guides/configure-logging.html#log-deduplication for more options.)
# (objective pid=13713)   warnings.warn( [repeated 4x across cluster]
# (objective pid=13843) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 14x across cluster]
# (objective pid=13843)   warnings.warn( [repeated 14x across cluster]
# (objective pid=14409) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 15x across cluster]
# (objective pid=14409)   warnings.warn( [repeated 15x across cluster]
# (objective pid=14508) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 21x across cluster]
# (objective pid=14508)   warnings.warn( [repeated 21x across cluster]
# (objective pid=15107) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 14x across cluster]
# (objective pid=15107)   warnings.warn( [repeated 14x across cluster]
# (objective pid=15306) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 19x across cluster]
# (objective pid=15306)   warnings.warn( [repeated 19x across cluster]
# (objective pid=15400) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 13x across cluster]
# (objective pid=15400)   warnings.warn( [repeated 13x across cluster]
# (objective pid=15796) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 14x across cluster]
# (objective pid=15796)   warnings.warn( [repeated 14x across cluster]
# (objective pid=16096) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 15x across cluster]
# (objective pid=16096)   warnings.warn( [repeated 15x across cluster]
# (objective pid=16293) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 15x across cluster]
# (objective pid=16293)   warnings.warn( [repeated 15x across cluster]
# (objective pid=16595) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 18x across cluster]
# (objective pid=16595)   warnings.warn( [repeated 18x across cluster]
# (objective pid=16693) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 18x across cluster]
# (objective pid=16693)   warnings.warn( [repeated 18x across cluster]
# (objective pid=16988) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 8x across cluster]
# (objective pid=16988)   warnings.warn( [repeated 8x across cluster]
# (objective pid=16988) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 10x across cluster]
# (objective pid=16988)   warnings.warn( [repeated 10x across cluster]
# (objective pid=17089) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 13x across cluster]
# (objective pid=17089)   warnings.warn( [repeated 13x across cluster]
# (objective pid=17386) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 13x across cluster]
# (objective pid=17386)   warnings.warn( [repeated 13x across cluster]
# (objective pid=17790) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 11x across cluster]
# (objective pid=17790)   warnings.warn( [repeated 11x across cluster]
# (objective pid=17989) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 8x across cluster]
# (objective pid=17989)   warnings.warn( [repeated 8x across cluster]
# (objective pid=18088) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 8x across cluster]
# (objective pid=18088)   warnings.warn( [repeated 8x across cluster]
# (objective pid=18414) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 11x across cluster]
# (objective pid=18414)   warnings.warn( [repeated 11x across cluster]
# (objective pid=18199) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 9x across cluster]
# (objective pid=18199)   warnings.warn( [repeated 9x across cluster]
# (objective pid=18088) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 13x across cluster]
# (objective pid=18088)   warnings.warn( [repeated 13x across cluster]
# (objective pid=18938) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 18x across cluster]
# (objective pid=18938)   warnings.warn( [repeated 18x across cluster]
# (objective pid=19335) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 14x across cluster]
# (objective pid=19335)   warnings.warn( [repeated 14x across cluster]
# (objective pid=19434) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 12x across cluster]
# (objective pid=19434)   warnings.warn( [repeated 12x across cluster]
# (objective pid=19434) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 13x across cluster]
# (objective pid=19434)   warnings.warn( [repeated 13x across cluster]
# (objective pid=19825) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 13x across cluster]
# (objective pid=19825)   warnings.warn( [repeated 13x across cluster]
# (objective pid=20233) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 10x across cluster]
# (objective pid=20233)   warnings.warn( [repeated 10x across cluster]
# (objective pid=20127) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 12x across cluster]
# (objective pid=20127)   warnings.warn( [repeated 12x across cluster]
# (objective pid=20233) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 14x across cluster]
# (objective pid=20233)   warnings.warn( [repeated 14x across cluster]
# (objective pid=20742) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 15x across cluster]
# (objective pid=20742)   warnings.warn( [repeated 15x across cluster]
# (objective pid=20941) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 14x across cluster]
# (objective pid=20941)   warnings.warn( [repeated 14x across cluster]
# (objective pid=21041) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 15x across cluster]
# (objective pid=21041)   warnings.warn( [repeated 15x across cluster]
# (objective pid=21140) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 10x across cluster]
# (objective pid=21140)   warnings.warn( [repeated 10x across cluster]
# (objective pid=21751) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 14x across cluster]
# (objective pid=21751)   warnings.warn( [repeated 14x across cluster]
# (objective pid=21552) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 15x across cluster]
# (objective pid=21552)   warnings.warn( [repeated 15x across cluster]
# (objective pid=22051) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 15x across cluster]
# (objective pid=22051)   warnings.warn( [repeated 15x across cluster]
# (objective pid=22350) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 15x across cluster]
# (objective pid=22350)   warnings.warn( [repeated 15x across cluster]
# (objective pid=22549) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 19x across cluster]
# (objective pid=22549)   warnings.warn( [repeated 19x across cluster]
# (objective pid=22749) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 14x across cluster]
# (objective pid=22749)   warnings.warn( [repeated 14x across cluster]
# (objective pid=23242) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 19x across cluster]
# (objective pid=23242)   warnings.warn( [repeated 19x across cluster]
# (objective pid=23342) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 15x across cluster]
# (objective pid=23342)   warnings.warn( [repeated 15x across cluster]
# (objective pid=23640) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 15x across cluster]
# (objective pid=23640)   warnings.warn( [repeated 15x across cluster]
# (objective pid=23939) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 16x across cluster]
# (objective pid=23939)   warnings.warn( [repeated 16x across cluster]
# (objective pid=24039) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 17x across cluster]
# (objective pid=24039)   warnings.warn( [repeated 17x across cluster]
# (objective pid=24337) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 16x across cluster]
# (objective pid=24337)   warnings.warn( [repeated 16x across cluster]
# (objective pid=24731) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 12x across cluster]
# (objective pid=24731)   warnings.warn( [repeated 12x across cluster]
# (objective pid=25029) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 21x across cluster]
# (objective pid=25029)   warnings.warn( [repeated 21x across cluster]
# (objective pid=25327) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 18x across cluster]
# (objective pid=25327)   warnings.warn( [repeated 18x across cluster]
# (objective pid=25420) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 13x across cluster]
# (objective pid=25420)   warnings.warn( [repeated 13x across cluster]
# (objective pid=25817) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 18x across cluster]
# (objective pid=25817)   warnings.warn( [repeated 18x across cluster]
# (objective pid=26118) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 15x across cluster]
# (objective pid=26118)   warnings.warn( [repeated 15x across cluster]
# (objective pid=26217) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 17x across cluster]
# (objective pid=26217)   warnings.warn( [repeated 17x across cluster]
# (objective pid=26808) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 18x across cluster]
# (objective pid=26808)   warnings.warn( [repeated 18x across cluster]
# (objective pid=26808) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 17x across cluster]
# (objective pid=26808)   warnings.warn( [repeated 17x across cluster]
# (objective pid=27307) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 13x across cluster]
# (objective pid=27307)   warnings.warn( [repeated 13x across cluster]
# (objective pid=27606) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 16x across cluster]
# (objective pid=27606)   warnings.warn( [repeated 16x across cluster]
# (objective pid=27606) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 18x across cluster]
# (objective pid=27606)   warnings.warn( [repeated 18x across cluster]
# (objective pid=28004) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 14x across cluster]
# (objective pid=28004)   warnings.warn( [repeated 14x across cluster]
# (objective pid=27904) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 17x across cluster]
# (objective pid=27904)   warnings.warn( [repeated 17x across cluster]
# (objective pid=28400) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 19x across cluster]
# (objective pid=28400)   warnings.warn( [repeated 19x across cluster]
# (objective pid=28696) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 18x across cluster]
# (objective pid=28696)   warnings.warn( [repeated 18x across cluster]
# (objective pid=28996) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 18x across cluster]
# (objective pid=28996)   warnings.warn( [repeated 18x across cluster]
# (objective pid=29320) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 18x across cluster]
# (objective pid=29320)   warnings.warn( [repeated 18x across cluster]
# (objective pid=29726) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 18x across cluster]
# (objective pid=29726)   warnings.warn( [repeated 18x across cluster]
# (objective pid=30120) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 18x across cluster]
# (objective pid=30120)   warnings.warn( [repeated 18x across cluster]
# (objective pid=30318) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 15x across cluster]
# (objective pid=30318)   warnings.warn( [repeated 15x across cluster]
# (objective pid=30417) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 13x across cluster]
# (objective pid=30417)   warnings.warn( [repeated 13x across cluster]
# (objective pid=30817) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 17x across cluster]
# (objective pid=30817)   warnings.warn( [repeated 17x across cluster]
# (objective pid=31017) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 17x across cluster]
# (objective pid=31017)   warnings.warn( [repeated 17x across cluster]
# (objective pid=31116) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 15x across cluster]
# (objective pid=31116)   warnings.warn( [repeated 15x across cluster]
# (objective pid=31708) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 18x across cluster]
# (objective pid=31708)   warnings.warn( [repeated 18x across cluster]
# (objective pid=31907) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 13x across cluster]
# (objective pid=31907)   warnings.warn( [repeated 13x across cluster]
# (objective pid=32008) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 16x across cluster]
# (objective pid=32008)   warnings.warn( [repeated 16x across cluster]
# (objective pid=32205) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 17x across cluster]
# (objective pid=32205)   warnings.warn( [repeated 17x across cluster]
# (objective pid=32604) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 16x across cluster]
# (objective pid=32604)   warnings.warn( [repeated 16x across cluster]
# (objective pid=32924) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 14x across cluster]
# (objective pid=32924)   warnings.warn( [repeated 14x across cluster]
# (objective pid=33316) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 15x across cluster]
# (objective pid=33316)   warnings.warn( [repeated 15x across cluster]
# (objective pid=33216) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 18x across cluster]
# (objective pid=33216)   warnings.warn( [repeated 18x across cluster]
# (objective pid=33714) /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8. [repeated 12x across cluster]
# (objective pid=33714)   warnings.warn( [repeated 12x across cluster]
# 2025-01-29 15:34:25,694	INFO tune.py:1009 -- Wrote the latest version of all result files and experiment state to '/home/rahul_e_dev/ray_results/objective_2025-01-29_15-27-05' in 0.0491s.
# 2025-01-29 15:34:25,748	INFO tune.py:1041 -- Total run time: 437.88 seconds (437.76 seconds for the tuning loop).

# %%
from sklearn.model_selection import TunedThresholdClassifierCV

best_result = results.get_best_result()
pipeline = get_pipeline()
config = {k:v for k,v in best_result.config.items() if k in pipeline.get_params()}
pipeline.set_params(**config)

pipeline = pipeline.fit(X_train_val, y_train_val)

kfold = ContinuousStratifiedKFold(n_splits=3)
th_pipeline = TunedThresholdClassifierCV(pipeline, scoring='f1', cv=kfold, thresholds=500, random_state=42)
th_pipeline.fit(X_train_val, y_train_val)

y_test_pred_prob = th_pipeline.predict_proba(X_test)[:, 1]
y_test_pred = th_pipeline.predict(X_test)
test_scores = calc_scores(y_test_pred_prob, y_test_pred, y_test.to_numpy())
test_scores = {k: np.round(v, 3) for k, v in test_scores.items()}
test_scores
# Out:
# /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# {'accuracy': 0.817,
#  'balanced_accuracy': 0.609,
#  'f1': 0.284,
#  'precision': 0.241,
#  'recall': 0.345,
#  'roc_auc': 0.69,
#  'average_precision': 0.242,
#  'specificity': 0.873,
#  'sensitivity': 0.345,
#  'test_delong_auc': 0.69,
#  'lb': 0.619,
#  'ub': 0.762}

# %%
best_result.metrics_dataframe
# Out:
#    accuracy  balanced_accuracy        f1  precision    recall   roc_auc  \
# 0   0.89243           0.606906  0.274194    0.34375  0.253731  0.700601
#
#    average_precision  specificity  sensitivity  test_delong_auc  ...  \
# 0           0.254184     0.959124     0.253731         0.700601  ...
#
#    config/lgbmclassifier__reg_lambda  config/lgbmclassifier__num_leaves  \
# 0                           0.005829                                126
#
#    config/lgbmclassifier__subsample config/lgbmclassifier__colsample_bytree  \
# 0                          0.302697                                0.114704
#
#    config/lgbmclassifier__min_child_samples  config/lgbmclassifier__n_jobs  \
# 0                                        57                              4
#
#   config/lgbmclassifier__random_state config/lgbmclassifier__scale_pos_weight  \
# 0                                  42                                      94
#
#    config/lgbmclassifier__n_estimators  config/lgbmclassifier__max_depth
# 0                                  619                                35
#
# [1 rows x 43 columns]

# %%
import dill

with open('./saved_models/parasite.pkl', 'wb') as outfile:
    dill.dump(th_pipeline, outfile)

# %%
# from sklearn.model_selection import TunedThresholdClassifierCV

# best_result = results.get_best_result()
# pipeline = get_pipeline()
# config = {k:v for k,v in best_result.config.items() if k in pipeline.get_params()}
# pipeline.set_params(**config)

# pipeline = pipeline.fit(X_train_val, y_train_val)

# kfold = ContinuousStratifiedKFold(n_splits=3)
# th_pipeline = TunedThresholdClassifierCV(pipeline, scoring='f1', cv=kfold, thresholds=500, random_state=42)
# th_pipeline.fit(X_train_val, y_train_val)

# y_test_pred_prob = th_pipeline.predict_proba(X_test)[:, 1]
# y_test_pred = th_pipeline.predict(X_test)
# test_scores = calc_scores(y_test_pred_prob, y_test_pred, y_test.to_numpy())
# test_scores = {k: np.round(v, 3) for k, v in test_scores.items()}
# test_scores
# Out:
# /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /home/rahul_e_dev/micromamba/envs/bio/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# {'accuracy': 0.872,
#  'balanced_accuracy': 0.644,
#  'f1': 0.322,
#  'precision': 0.284,
#  'recall': 0.372,
#  'roc_auc': 0.756,
#  'average_precision': 0.267,
#  'specificity': 0.916,
#  'sensitivity': 0.372,
#  'test_delong_auc': 0.756,
#  'lb': 0.701,
#  'ub': 0.812}

# %%
# best_result.metrics_dataframe
# Out:
#    accuracy  balanced_accuracy   f1  precision    recall   roc_auc  \
# 0  0.922764           0.593198  0.3       0.56  0.196721  0.741211
#
#    average_precision  specificity  sensitivity  test_delong_auc  ...  \
# 0           0.309812     0.983776     0.196721         0.741211  ...
#
#    config/lgbmclassifier__reg_lambda  config/lgbmclassifier__num_leaves  \
# 0                       4.851556e-08                                179
#
#    config/lgbmclassifier__subsample config/lgbmclassifier__colsample_bytree  \
# 0                          0.281039                                 0.13059
#
#    config/lgbmclassifier__min_child_samples  config/lgbmclassifier__n_jobs  \
# 0                                        18                              4
#
#   config/lgbmclassifier__random_state config/lgbmclassifier__scale_pos_weight  \
# 0                                  42                                      92
#
#    config/lgbmclassifier__n_estimators  config/lgbmclassifier__max_depth
# 0                                  513                                21
#
# [1 rows x 43 columns]
